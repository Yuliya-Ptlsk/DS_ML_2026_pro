# %%
from scripts.visualize import count_samples_balance, visualize_raw_data
from scripts.utils import create_image_mask_pairs
import random

# %% [markdown]
# Analyze balance of images with tumor and without

# %%
samples = create_image_mask_pairs("../data/kaggle_3m")

positive_samples, negative_samples = count_samples_balance(samples)
# Out:
# Total samples: 3929
# MRI with tumor: 1373 / 34.95%
# MRI without tumor: 2556 / 65.05%

# %% [markdown]
# Visualize 5 random raw image-mask pairs WITH tumor

# %%
title = "Raw Data With Tumor"

visualize_raw_data(random.sample(positive_samples, 5), title)

# %% [markdown]
# Visualize 5 random raw image-mask pairs WITHOUT tumor

# %%
title = "Raw Data Without Tumor"

visualize_raw_data(random.sample(negative_samples, 5), title)
